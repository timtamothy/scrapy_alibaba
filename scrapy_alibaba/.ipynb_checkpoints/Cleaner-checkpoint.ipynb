# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/swang/scrapy_alibaba/supplier_B_clean.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                  business_supplier  \
# 0           0          Shanghai Lipu Electric Lighting Co., Ltd.
# 1           1  Quanzhou Orientrise Horticulture Products Co.,...
# 2           2                      Sinowell (Shanghai) Co., Ltd.
# 3           3  Changzhou City Wujin Shinder Lighting Applianc...
# 4           4                  Huizhou HongYi Lighting Co., Ltd.
#
#                                         contacts_url    gold_status  \
# 0               lpzm.en.alibaba.com/contactinfo.html  Gold Supplier
# 1           growstar.en.alibaba.com/contactinfo.html  Gold Supplier
# 2           sinowell.en.alibaba.com/contactinfo.html       Supplier
# 3            czxinde.en.alibaba.com/contactinfo.html  Gold Supplier
# 4  hydroponics-products.en.alibaba.com/contactinf...  Gold Supplier
#
#    gold_years                                      main_products  \
# 0          12  Floodlight, Street Light, Ballast, Ignitor, LE...
# ...

# %%
df['contacts_url'] = 'https://'+df['contacts_url'].astype(str)
df['supplier_url'] = 'https://'+df['supplier_url'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5628 entries, 0 to 5627
# Data columns (total 7 columns):
# Unnamed: 0           5628 non-null int64
# business_supplier    5628 non-null object
# contacts_url         5628 non-null object
# gold_status          5628 non-null object
# gold_years           5628 non-null int64
# main_products        5628 non-null object
# supplier_url         5628 non-null object
# dtypes: int64(2), object(5)
# memory usage: 307.9+ KB

# %%
df.head()
# Out:
#    Unnamed: 0                                  business_supplier  \
# 0           0          Shanghai Lipu Electric Lighting Co., Ltd.
# 1           1  Quanzhou Orientrise Horticulture Products Co.,...
# 2           2                      Sinowell (Shanghai) Co., Ltd.
# 3           3  Changzhou City Wujin Shinder Lighting Applianc...
# 4           4                  Huizhou HongYi Lighting Co., Ltd.
#
#                                         contacts_url    gold_status  \
# 0       https://lpzm.en.alibaba.com/contactinfo.html  Gold Supplier
# 1   https://growstar.en.alibaba.com/contactinfo.html  Gold Supplier
# 2   https://sinowell.en.alibaba.com/contactinfo.html       Supplier
# 3    https://czxinde.en.alibaba.com/contactinfo.html  Gold Supplier
# 4  https://hydroponics-products.en.alibaba.com/co...  Gold Supplier
#
#    gold_years                                      main_products  \
# 0          12  Floodlight, Street Light, Ballast, Ignitor, LE...
# ...

# %%
df.to_csv(r'/Users/swang/scrapy_alibaba/supplier_BCleanhttps.csv')
