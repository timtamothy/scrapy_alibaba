# %%
import numpy as np
import pandas as pd

# %%
df0 = pd.read_csv('/Users/swang/scrapy_alibaba/Scrapy Data/supplier_name_0_clean.csv')
df1 = pd.read_csv('/Users/swang/scrapy_alibaba/Scrapy Data/supplier_name_1_clean.csv')
df2 = pd.read_csv('/Users/swang/scrapy_alibaba/Scrapy Data/supplier_name_2_clean.csv')
dfend = pd.read_csv('/Users/swang/scrapy_alibaba/Scrapy Data/supplier_name_end_clean.csv')

# %%
dfall = pd.concat([df0, df1, df2, dfend], ignore_index=True)

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133745 entries, 0 to 133744
# Data columns (total 7 columns):
# Unnamed: 0           133745 non-null int64
# business_supplier    133744 non-null object
# contacts_url         133745 non-null object
# gold_status          133745 non-null object
# gold_years           133745 non-null int64
# main_products        133745 non-null object
# supplier_url         133745 non-null object
# dtypes: int64(2), object(5)
# memory usage: 7.1+ MB

# %%
dfall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 496355 entries, 0 to 113758
# Data columns (total 7 columns):
# Unnamed: 0           496355 non-null int64
# business_supplier    496351 non-null object
# contacts_url         496355 non-null object
# gold_status          496355 non-null object
# gold_years           496355 non-null object
# main_products        496355 non-null object
# supplier_url         496355 non-null object
# dtypes: int64(1), object(6)
# memory usage: 30.3+ MB

# %%
dfall.reset_index(drop=True)
# Out:
#         Unnamed: 0                                  business_supplier  \
# 0                0                      Dalian Holy Trading Co., Ltd.
# 1                1  Ronix (Zhangjiagang Bonded Area) Trading Co., ...
# 2                2                    Shanghai UB Machinery Co., Ltd.
# 3                3                   Suzhou Matthew Consultation Ltd.
# 4                4       Cixi Modern Electric Industrialist Co., Ltd.
# 5                5  Ronix (Zhangjiagang Bonded Area) Trading Co., ...
# 6                6                                    JCOOL CO., LTD.
# 7                7               HUNG CHING TZAN ENTERPRISE CO., LTD.
# 8                8       Taian Beacon Machine Manufacturing Co., Ltd.
# 9                9  Hengshui Hao Fa Rubber & Plastic Products Co.,...
# 10              10                Ruian Jia Beir Auto Parts Co., Ltd.
# 11              11                   Shanghai AOYI Electric Co., Ltd.
# ...

# %%
dfall.drop(dfall['unnamed'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/scrapy/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'unnamed'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-f12e73cdcb18> in <module>
# ...

# %%
df2 = df.drop_duplicates(subset='contacts_url', keep='first')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123761 entries, 0 to 1703745
# Data columns (total 6 columns):
# business_supplier    123760 non-null object
# contacts_url         123761 non-null object
# gold_status          123761 non-null object
# gold_years           123761 non-null int64
# main_products        123761 non-null object
# supplier_url         123761 non-null object
# dtypes: int64(1), object(5)
# memory usage: 6.6+ MB

# %%
df2['contacts_url'] = df2['contacts_url'].apply(lambda x: x.replace('//',''))
df2['supplier_url'] = df2['supplier_url'].apply(lambda x: x.replace('//',''))
df2['main_products'] = df2['main_products'].apply(lambda x: x.replace(',', ', '))
# Out:
# /Users/swang/anaconda3/envs/scrapy/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/swang/anaconda3/envs/scrapy/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/swang/anaconda3/envs/scrapy/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df2 = df2.reset_index(drop=True)

# %%
df2.to_csv(r'/Users/swang/scrapy_alibaba/Scrapy Data/supplier_name_2_clean.csv')

# %%
df2.groupby(df2.gold_status).count()
# Out:
#                  business_supplier  contacts_url  gold_years  main_products  \
# gold_status
# Gold Supplier               107791        107792      107792         107792
# Supplier                     15902         15902       15902          15902
# Trade Assurance                 67            67          67             67
#
#                  supplier_url
# gold_status
# Gold Supplier          107792
# Supplier                15902
# Trade Assurance            67

# %%
df2.head()
# Out:
#                                  business_supplier  \
# 0  Quanzhou Sangchuan Electric Equipment Co., Ltd.
# 1       Anhui Chinaland Solar Technology Co., Ltd.
# 2        Hangzhou Tonny Electric & Tools Co., Ltd.
# 3    Qingdao HenryD Wind Power Equipment Co., Ltd.
# 4    Zhejiang Ziri Electrical Technology Co., Ltd.
#
#                                      contacts_url    gold_status  gold_years  \
# 0         cnsanch.en.alibaba.com/contactinfo.html  Gold Supplier           6
# 1  chinalandsolar.en.alibaba.com/contactinfo.html       Supplier           3
# 2        tonytool.en.alibaba.com/contactinfo.html       Supplier          18
# 3          hldwtg.en.alibaba.com/contactinfo.html  Gold Supplier           5
# 4          chziri.en.alibaba.com/contactinfo.html       Supplier          11
#
#                                        main_products  \
# 0  Interver, Servo, Intelligent instrument, Power...
# 1  Solar Panel, Solar System (Inverter, Battery, ...
# ...
