# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('alibaba1.csv')

# %%
df.head()
# Out:
#                                         product_name  \
# 0  Walkie talkie Earphone Smile Logo Headphone Wi...
#
#                                        supplier_name
# 0  Shenzhen Rongwu Technology Development Co., Lt...

# %%
df['seller_years_on_alibaba']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/scrapy/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'seller_years_on_alibaba'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-ce2de5b851ab> in <module>
# ...

# %%
total pages = response.xpath('//div[@class='ui2-pagination-pages']/a[contains(@data-spm-anchor-id, "a2700.galleryofferlist.pagination.7")]/text()').extract
# Out:
#   File "<ipython-input-22-42bbdc6a92ca>", line 1
#     total pages = response.xpath('//div[@class='ui2-pagination-pages']/a[contains(@data-spm-anchor-id, "a2700.galleryofferlist.pagination.7")]/text()').extract
#               ^
# SyntaxError: invalid syntax
