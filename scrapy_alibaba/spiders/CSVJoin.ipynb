# %%
import pandas as pd
import numpy as np

# %%
df_original = pd.read_csv('supplier_BCleanhttps.csv')
dfprofile = pd.read_csv('supplier_BCprofile.csv')
dfcontacts = pd.read_csv('supplier_BCcontacts.csv')

# %%
df_original.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                    business_supplier  \
# 0          Shanghai Lipu Electric Lighting Co., Ltd.
# 1  Quanzhou Orientrise Horticulture Products Co.,...
# 2                      Sinowell (Shanghai) Co., Ltd.
# 3  Changzhou City Wujin Shinder Lighting Applianc...
# 4                  Huizhou HongYi Lighting Co., Ltd.
#
#                                         contacts_url    gold_status  \
# 0       https://lpzm.en.alibaba.com/contactinfo.html  Gold Supplier
# 1   https://growstar.en.alibaba.com/contactinfo.html  Gold Supplier
# 2   https://sinowell.en.alibaba.com/contactinfo.html       Supplier
# 3    https://czxinde.en.alibaba.com/contactinfo.html  Gold Supplier
# 4  https://hydroponics-products.en.alibaba.com/co...  Gold Supplier
#
# ...

# %%
df = df_original.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)

# %%
dfprofile.head()
# Out:
#                                         supplier_url  \
# 0  https://lpzm.en.alibaba.com/company_profile.ht...
# 1  https://growstar.en.alibaba.com/company_profil...
# 2  https://sinowell.en.alibaba.com/company_profil...
# 3  https://czxinde.en.alibaba.com/company_profile...
# 4  https://hydroponics-products.en.alibaba.com/co...
#
#                                        supplier_name  rating
# 0          Shanghai Lipu Electric Lighting Co., Ltd.     0.0
# 1  Quanzhou Orientrise Horticulture Products Co.,...     4.8
# 2             Sinowell (Shanghai) Co., Ltd.,Supplier     4.9
# 3  Changzhou City Wujin Shinder Lighting Applianc...     4.3
# 4                  Huizhou HongYi Lighting Co., Ltd.     4.9

# %%
dfcontacts.head()
# Out:
#                                          contact_url     contact_name  \
# 0       https://lpzm.en.alibaba.com/contactinfo.html      Ms. liz lin
# 1   https://growstar.en.alibaba.com/contactinfo.html              NaN
# 2   https://sinowell.en.alibaba.com/contactinfo.html    Mr. Roger Luo
# 3    https://czxinde.en.alibaba.com/contactinfo.html  Mr. Jacky Zueng
# 4  https://hydroponics-products.en.alibaba.com/co...     Mr. Bill Liu
#
#                    contact_dept  Telephone:  Mobile Phone:  Fax:  \
# 0                         Sales         0.0            0.0   0.0
# 1                           NaN         NaN            NaN   NaN
# 2  Director/CEO/General Manager         0.0            NaN   0.0
# 3                         Sales         0.0            0.0   0.0
# 4                           NaN         0.0            0.0   0.0
#
#                                             Address:    Zip: Country/Region:  \
# ...

# %%
dfprofile.columns = ['supplier_url', 'supplier_name_copy', 'rating']

# %%
dfprofile.head()
# Out:
#                                         supplier_url  \
# 0  https://lpzm.en.alibaba.com/company_profile.ht...
# 1  https://growstar.en.alibaba.com/company_profil...
# 2  https://sinowell.en.alibaba.com/company_profil...
# 3  https://czxinde.en.alibaba.com/company_profile...
# 4  https://hydroponics-products.en.alibaba.com/co...
#
#                                   supplier_name_copy  rating
# 0          Shanghai Lipu Electric Lighting Co., Ltd.     0.0
# 1  Quanzhou Orientrise Horticulture Products Co.,...     4.8
# 2             Sinowell (Shanghai) Co., Ltd.,Supplier     4.9
# 3  Changzhou City Wujin Shinder Lighting Applianc...     4.3
# 4                  Huizhou HongYi Lighting Co., Ltd.     4.9

# %%
dfcontacts.columns
# Out:
# Index(['contact_url', 'contact_name', 'contact_dept', 'Telephone:',
#        'Mobile Phone:', 'Fax:', 'Address:', 'Zip:', 'Country/Region:',
#        'Province/State:', 'City:'],
#       dtype='object')

# %%
dfcontacts.columns = ['contacts_url', 'contact_name', 'contact_dept', 'Telephone:',
       'Mobile Phone:', 'Fax:', 'Address:', 'Zip:', 'Country/Region:',
       'Province/State:', 'City:']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5628 entries, 0 to 5627
# Data columns (total 6 columns):
# business_supplier    5628 non-null object
# contacts_url         5628 non-null object
# gold_status          5628 non-null object
# gold_years           5628 non-null int64
# main_products        5628 non-null object
# supplier_url         5628 non-null object
# dtypes: int64(1), object(5)
# memory usage: 263.9+ KB

# %%
dfprofile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5586 entries, 0 to 5585
# Data columns (total 3 columns):
# supplier_url          5586 non-null object
# supplier_name_copy    5238 non-null object
# rating                4150 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 131.0+ KB

# %%
dfcontacts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5586 entries, 0 to 5585
# Data columns (total 11 columns):
# contacts_url       5586 non-null object
# contact_name       5159 non-null object
# contact_dept       4366 non-null object
# Telephone:         5084 non-null float64
# Mobile Phone:      4286 non-null float64
# Fax:               3011 non-null float64
# Address:           4989 non-null object
# Zip:               4434 non-null object
# Country/Region:    5277 non-null object
# Province/State:    4928 non-null object
# City:              4988 non-null object
# dtypes: float64(3), object(8)
# memory usage: 480.1+ KB

# %%
merge1 = df.merge(dfprofile, how='left', on='supplier_url')

# %%
merge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5628 entries, 0 to 5627
# Data columns (total 8 columns):
# business_supplier     5628 non-null object
# contacts_url          5628 non-null object
# gold_status           5628 non-null object
# gold_years            5628 non-null int64
# main_products         5628 non-null object
# supplier_url          5628 non-null object
# supplier_name_copy    5238 non-null object
# rating                4150 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 395.7+ KB

# %%
merge2 = merge1.merge(dfcontacts, how='left', on='contacts_url')

# %%
merge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5628 entries, 0 to 5627
# Data columns (total 18 columns):
# business_supplier     5628 non-null object
# contacts_url          5628 non-null object
# gold_status           5628 non-null object
# gold_years            5628 non-null int64
# main_products         5628 non-null object
# supplier_url          5628 non-null object
# supplier_name_copy    5238 non-null object
# rating                4150 non-null float64
# contact_name          5124 non-null object
# contact_dept          4347 non-null object
# Telephone:            5051 non-null float64
# Mobile Phone:         4266 non-null float64
# Fax:                  2986 non-null float64
# Address:              4959 non-null object
# Zip:                  4407 non-null object
# Country/Region:       5242 non-null object
# Province/State:       4897 non-null object
# City:                 4958 non-null object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 835.4+ KB

# %%
merge2.head()
# Out:
#                                    business_supplier  \
# 0          Shanghai Lipu Electric Lighting Co., Ltd.
# 1  Quanzhou Orientrise Horticulture Products Co.,...
# 2                      Sinowell (Shanghai) Co., Ltd.
# 3  Changzhou City Wujin Shinder Lighting Applianc...
# 4                  Huizhou HongYi Lighting Co., Ltd.
#
#                                         contacts_url    gold_status  \
# 0       https://lpzm.en.alibaba.com/contactinfo.html  Gold Supplier
# 1   https://growstar.en.alibaba.com/contactinfo.html  Gold Supplier
# 2   https://sinowell.en.alibaba.com/contactinfo.html       Supplier
# 3    https://czxinde.en.alibaba.com/contactinfo.html  Gold Supplier
# 4  https://hydroponics-products.en.alibaba.com/co...  Gold Supplier
#
#    gold_years                                      main_products  \
# 0          12  Floodlight, Street Light, Ballast, Ignitor, LE...
# 1           9  Grow Tent, Grow Pot, Bubble Bag, Inline Fan, C...
# ...

# %%
merge2['Address:'][1] = 'No. 2 Chongheng street, Qingmeng development zone'
merge2['Zip:'][1] = '362006'
merge2['Country/Region:'][1] = 'China'
merge2['Province/State:'][1] = 'Fujian'
merge2['City:'][1] = 'Quanzhou'
merge2['contact_name'][1] = 'Mr. Mark Orientrise'
merge2['contact_dept'][1] = 'Owner/Entrepreneur'
# Out:
# /Users/swang/anaconda3/envs/scrapy/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/swang/anaconda3/envs/scrapy/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/swang/anaconda3/envs/scrapy/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
merge2.head()
# Out:
#                                    business_supplier  \
# 0          Shanghai Lipu Electric Lighting Co., Ltd.
# 1  Quanzhou Orientrise Horticulture Products Co.,...
# 2                      Sinowell (Shanghai) Co., Ltd.
# 3  Changzhou City Wujin Shinder Lighting Applianc...
# 4                  Huizhou HongYi Lighting Co., Ltd.
#
#                                         contacts_url    gold_status  \
# 0       https://lpzm.en.alibaba.com/contactinfo.html  Gold Supplier
# 1   https://growstar.en.alibaba.com/contactinfo.html  Gold Supplier
# 2   https://sinowell.en.alibaba.com/contactinfo.html       Supplier
# 3    https://czxinde.en.alibaba.com/contactinfo.html  Gold Supplier
# 4  https://hydroponics-products.en.alibaba.com/co...  Gold Supplier
#
#    gold_years                                      main_products  \
# 0          12  Floodlight, Street Light, Ballast, Ignitor, LE...
# 1           9  Grow Tent, Grow Pot, Bubble Bag, Inline Fan, C...
# ...

# %%
merge2.to_csv('/Users/swang/scrapy_alibaba/MergedSuppliers.csv')

# %%
merge2 = merge2.drop(['Telephone:', 'Mobile Phone:', 'Fax:'], axis=1)

# %%
merge2.head()
# Out:
#                                    business_supplier  \
# 0          Shanghai Lipu Electric Lighting Co., Ltd.
# 1  Quanzhou Orientrise Horticulture Products Co.,...
# 2                      Sinowell (Shanghai) Co., Ltd.
# 3  Changzhou City Wujin Shinder Lighting Applianc...
# 4                  Huizhou HongYi Lighting Co., Ltd.
#
#                                         contacts_url    gold_status  \
# 0       https://lpzm.en.alibaba.com/contactinfo.html  Gold Supplier
# 1   https://growstar.en.alibaba.com/contactinfo.html  Gold Supplier
# 2   https://sinowell.en.alibaba.com/contactinfo.html       Supplier
# 3    https://czxinde.en.alibaba.com/contactinfo.html  Gold Supplier
# 4  https://hydroponics-products.en.alibaba.com/co...  Gold Supplier
#
#    gold_years                                      main_products  \
# 0          12  Floodlight, Street Light, Ballast, Ignitor, LE...
# 1           9  Grow Tent, Grow Pot, Bubble Bag, Inline Fan, C...
# ...
