# %%
import csv
import numpy as np
import pandas as pd

# %%
with open('/Users/swang/scrapy_alibaba/test_b_domain.csv', 'rt', encoding='utf8') as file:
            reader = csv.reader(file, delimiter=' ', quotechar='|')
            next(reader)
            url_list=[]
            for row in reader:
                for url in row:
                    url_list.append(url)

# %%
df = pd.read_csv('/Users/swang/scrapy_alibaba/test_b_domain.csv')

# %%
len(url_list[11000000:])
# Out:
# 383791

# %%
df.head()
# Out:
#                                    business_supplier  \
# 0          Shanghai Lipu Electric Lighting Co., Ltd.
# 1  Quanzhou Orientrise Horticulture Products Co.,...
# 2                      Sinowell (Shanghai) Co., Ltd.
# 3  Changzhou City Wujin Shinder Lighting Applianc...
# 4                  Huizhou HongYi Lighting Co., Ltd.
#
#                                         contacts_url    gold_status  \
# 0             //lpzm.en.alibaba.com/contactinfo.html  Gold Supplier
# 1         //growstar.en.alibaba.com/contactinfo.html  Gold Supplier
# 2         //sinowell.en.alibaba.com/contactinfo.html       Supplier
# 3          //czxinde.en.alibaba.com/contactinfo.html  Gold Supplier
# 4  //hydroponics-products.en.alibaba.com/contacti...  Gold Supplier
#
#    gold_years                                      main_products  \
# 0          12  Floodlight,Street Light,Ballast,Ignitor,LED Fl...
# 1           9  Grow Tent,Grow Pot,Bubble Bag,Inline Fan,Carbo...
# 2          11  Ballast,Reflector,Bulb,Filter,Inline Fan,Refle...
# 3          13  Flood Light,street light,Metal Halide lamp,led...
# 4           7  Grow Light Reflector,Carbon Filter,Grow Tent,D...
#
#                                         supplier_url
# 0  //lpzm.en.alibaba.com/company_profile.html#top...
# 1  //growstar.en.alibaba.com/company_profile.html...
# 2  //sinowell.en.alibaba.com/company_profile.html...
# 3  //czxinde.en.alibaba.com/company_profile.html#...
# 4  //hydroponics-products.en.alibaba.com/company_...

# %%
df2 = df.drop_duplicates(subset='contacts_url', keep='first')

# %%
df.info()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12006 entries, 0 to 12005
# Data columns (total 6 columns):
# business_supplier    12006 non-null object
# contacts_url         12006 non-null object
# gold_status          12006 non-null object
# gold_years           12006 non-null int64
# main_products        12006 non-null object
# supplier_url         12006 non-null object
# dtypes: int64(1), object(5)
# memory usage: 562.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5628 entries, 0 to 12005
# Data columns (total 6 columns):
# business_supplier    5628 non-null object
# contacts_url         5628 non-null object
# gold_status          5628 non-null object
# gold_years           5628 non-null int64
# main_products        5628 non-null object
# supplier_url         5628 non-null object
# dtypes: int64(1), object(5)
# memory usage: 307.8+ KB

# %%
df2['contacts_url'] = df2['contacts_url'].apply(lambda x: x.replace('//',''))
df2['supplier_url'] = df2['supplier_url'].apply(lambda x: x.replace('//',''))
df2['main_products'] = df2['main_products'].apply(lambda x: x.replace(',', ', '))
# Out:
# /Users/swang/anaconda3/envs/scrapy/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/swang/anaconda3/envs/scrapy/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/swang/anaconda3/envs/scrapy/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df2 = df2.reset_index(drop=True)

# %%
df2.to_csv(r'/Users/swang/scrapy_alibaba/supplier_B_clean.csv')

# %%
df2.groupby(df2.gold_status).count()
# Out:
#                business_supplier  contacts_url  gold_years  main_products  \
# gold_status
# Gold Supplier               4481          4481        4481           4481
# Supplier                    1147          1147        1147           1147
#
#                supplier_url
# gold_status
# Gold Supplier          4481
# Supplier               1147

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5628 entries, 0 to 12005
# Data columns (total 6 columns):
# business_supplier    5628 non-null object
# contacts_url         5628 non-null object
# gold_status          5628 non-null object
# gold_years           5628 non-null int64
# main_products        5628 non-null object
# supplier_url         5628 non-null object
# dtypes: int64(1), object(5)
# memory usage: 467.8+ KB

# %%
df3 = df2[df2['gold_years'] > 5]

# %%
df3.count()
# Out:
# business_supplier    2488
# contacts_url         2488
# gold_status          2488
# gold_years           2488
# main_products        2488
# supplier_url         2488
# dtype: int64

# %%
df4 = df3[df3['gold_status']=='Gold Supplier']

# %%
df4.count()
# Out:
# business_supplier    1793
# contacts_url         1793
# gold_status          1793
# gold_years           1793
# main_products        1793
# supplier_url         1793
# dtype: int64

# %%
df4.head()
# Out:
#                                    business_supplier  \
# 0          Shanghai Lipu Electric Lighting Co., Ltd.
# 1  Quanzhou Orientrise Horticulture Products Co.,...
# 3  Changzhou City Wujin Shinder Lighting Applianc...
# 4                  Huizhou HongYi Lighting Co., Ltd.
# 5                    Lanxi Bistar Lighting Co., Ltd.
#
#                                         contacts_url    gold_status  \
# 0               lpzm.en.alibaba.com/contactinfo.html  Gold Supplier
# 1           growstar.en.alibaba.com/contactinfo.html  Gold Supplier
# 3            czxinde.en.alibaba.com/contactinfo.html  Gold Supplier
# 4  hydroponics-products.en.alibaba.com/contactinf...  Gold Supplier
# 5             bistar.en.alibaba.com/contactinfo.html  Gold Supplier
#
#    gold_years                                      main_products  \
# 0          12  Floodlight, Street Light, Ballast, Ignitor, LE...
# 1           9  Grow Tent, Grow Pot, Bubble Bag, Inline Fan, C...
# 3          13  Flood Light, street light, Metal Halide lamp, ...
# 4           7  Grow Light Reflector, Carbon Filter, Grow Tent...
# 5          13                           Lamp, Electronic Ballast
#
#                                         supplier_url
# 0  lpzm.en.alibaba.com/company_profile.html#top-n...
# 1  growstar.en.alibaba.com/company_profile.html#t...
# 3  czxinde.en.alibaba.com/company_profile.html#to...
# 4  hydroponics-products.en.alibaba.com/company_pr...
# 5  bistar.en.alibaba.com/company_profile.html#top...

# %%
df2.contacts_url.tolist()
# Out:
# ['lpzm.en.alibaba.com/contactinfo.html',
#  'growstar.en.alibaba.com/contactinfo.html',
#  'sinowell.en.alibaba.com/contactinfo.html',
#  'czxinde.en.alibaba.com/contactinfo.html',
#  'hydroponics-products.en.alibaba.com/contactinfo.html',
#  'bistar.en.alibaba.com/contactinfo.html',
#  'horti-king.en.alibaba.com/contactinfo.html',
#  'jr-lighting.en.alibaba.com/contactinfo.html',
#  'millenium.en.alibaba.com/contactinfo.html',
#  'jayotech.en.alibaba.com/contactinfo.html',
#  'raylux.en.alibaba.com/contactinfo.html',
#  'risenlighting.en.alibaba.com/contactinfo.html',
#  'sino-well.en.alibaba.com/contactinfo.html',
#  'new-viewhid.en.alibaba.com/contactinfo.html',
#  'ycgd.en.alibaba.com/contactinfo.html',
#  'chinuphydro.en.alibaba.com/contactinfo.html',
#  'gwellgroup.en.alibaba.com/contactinfo.html',
#  'hortlight.en.alibaba.com/contactinfo.html',
#  'hzhortiking.en.alibaba.com/contactinfo.html',
#  'virex.en.alibaba.com/contactinfo.html',
#  'kinggrow.en.alibaba.com/contactinfo.html',
#  'tri-lite.en.alibaba.com/contactinfo.html',
#  'ebm-lighting.en.alibaba.com/contactinfo.html',
#  'okayhydro.en.alibaba.com/contactinfo.html',
#  'gzdao.en.alibaba.com/contactinfo.html',
#  'evitekhid.en.alibaba.com/contactinfo.html',
#  'longlifecar.en.alibaba.com/contactinfo.html',
#  'gzonelight.en.alibaba.com/contactinfo.html',
#  'xuzunhk.en.alibaba.com/contactinfo.html',
#  'padalight.en.alibaba.com/contactinfo.html',
#  'gpusi.en.alibaba.com/contactinfo.html',
#  'gt-light.en.alibaba.com/contactinfo.html',
#  'honnex.en.alibaba.com/contactinfo.html',
#  'tepro.en.alibaba.com/contactinfo.html',
#  'milleniumhorticulture.en.alibaba.com/contactinfo.html',
#  'novotek.en.alibaba.com/contactinfo.html',
#  'wxblpzm.en.alibaba.com/contactinfo.html',
#  'deplux.en.alibaba.com/contactinfo.html',
#  'fsmyu.en.alibaba.com/contactinfo.html',
#  'tonhilighting.en.alibaba.com/contactinfo.html',
#  'fitbright.en.alibaba.com/contactinfo.html',
#  'dglighting.en.alibaba.com/contactinfo.html',
#  'brandon.en.alibaba.com/contactinfo.html',
#  'halcon.en.alibaba.com/contactinfo.html',
#  'tiaoshun.en.alibaba.com/contactinfo.html',
#  'fullwintech.en.alibaba.com/contactinfo.html',
#  'bayangzm.en.alibaba.com/contactinfo.html',
#  'zschanglong.en.alibaba.com/contactinfo.html',
#  'bdtrading.en.alibaba.com/contactinfo.html',
#  'hualinglighting.en.alibaba.com/contactinfo.html',
#  'meiyunlighting.en.alibaba.com/contactinfo.html',
#  'delixi-elc.en.alibaba.com/contactinfo.html',
#  'light-acclaim.en.alibaba.com/contactinfo.html',
#  'lightbest.en.alibaba.com/contactinfo.html',
#  'lonyung.en.alibaba.com/contactinfo.html',
#  'welthink.en.alibaba.com/contactinfo.html',
#  'tydz.en.alibaba.com/contactinfo.html',
#  'shlipuzm.en.alibaba.com/contactinfo.html',
#  'shenming-growlight.en.alibaba.com/contactinfo.html',
#  'hengxiong.en.alibaba.com/contactinfo.html',
#  'bluesunpv.en.alibaba.com/contactinfo.html',
#  'zjwealth.en.alibaba.com/contactinfo.html',
#  'crpump.en.alibaba.com/contactinfo.html',
#  'cncsc.en.alibaba.com/contactinfo.html',
#  'gzfenlin.en.alibaba.com/contactinfo.html',
#  'kshym.en.alibaba.com/contactinfo.html',
#  'blooming-sprayer.en.alibaba.com/contactinfo.html',
#  'toption.en.alibaba.com/contactinfo.html',
#  'sjzhf.en.alibaba.com/contactinfo.html',
#  'sunflowersolar.en.alibaba.com/contactinfo.html',
#  'cntriumph.en.alibaba.com/contactinfo.html',
#  'lantsun.en.alibaba.com/contactinfo.html',
#  'cnfortek.en.alibaba.com/contactinfo.html',
#  'szhixem.en.alibaba.com/contactinfo.html',
#  'aescar.en.alibaba.com/contactinfo.html',
#  'ugghid.en.alibaba.com/contactinfo.html',
#  'mhcarparts.en.alibaba.com/contactinfo.html',
#  'liwin.en.alibaba.com/contactinfo.html',
#  'speedlight.en.alibaba.com/contactinfo.html',
#  'dlxhkj.en.alibaba.com/contactinfo.html',
#  'dsengineparts.en.alibaba.com/contactinfo.html',
#  'superbattery.en.alibaba.com/contactinfo.html',
#  'ledtubelight.en.alibaba.com/contactinfo.html',
#  'hz-led.en.alibaba.com/contactinfo.html',
#  'bwelectr.en.alibaba.com/contactinfo.html',
#  'ahlr.en.alibaba.com/contactinfo.html',
#  'lvdengxia.en.alibaba.com/contactinfo.html',
#  'chungxin.en.alibaba.com/contactinfo.html',
#  'sznumber.en.alibaba.com/contactinfo.html',
#  'csxldl.en.alibaba.com/contactinfo.html',
#  'snxin.en.alibaba.com/contactinfo.html',
#  'sunnyelectrical.en.alibaba.com/contactinfo.html',
#  'renownuv.en.alibaba.com/contactinfo.html',
#  'shyitu.en.alibaba.com/contactinfo.html',
#  'xyelectronics.en.alibaba.com/contactinfo.html',
#  'hampool.en.alibaba.com/contactinfo.html',
#  'baotenlink.en.alibaba.com/contactinfo.html',
#  'tittrick01.en.alibaba.com/contactinfo.html',
#  'sentlon.en.alibaba.com/contactinfo.html',
#  'bofit.en.alibaba.com/contactinfo.html',
#  'yqshicheng.en.alibaba.com/contactinfo.html',
#  'wubai.en.alibaba.com/contactinfo.html',
#  'gl-copper.en.alibaba.com/contactinfo.html',
#  'htll.en.alibaba.com/contactinfo.html',
#  'gdbosi.en.alibaba.com/contactinfo.html',
#  'baidadianqi.en.alibaba.com/contactinfo.html',
#  'flashcure.en.alibaba.com/contactinfo.html',
#  'txuv.en.alibaba.com/contactinfo.html',
#  'goldeneagle.en.alibaba.com/contactinfo.html',
#  'zsouge.en.alibaba.com/contactinfo.html',
#  'cddzh.en.alibaba.com/contactinfo.html',
#  'lme.en.alibaba.com/contactinfo.html',
#  'mingyudacn.en.alibaba.com/contactinfo.html',
#  'zvepower.en.alibaba.com/contactinfo.html',
#  'hkxx.en.alibaba.com/contactinfo.html',
#  'dernfu.en.alibaba.com/contactinfo.html',
#  'jysuokang.en.alibaba.com/contactinfo.html',
#  'uvbest.en.alibaba.com/contactinfo.html',
#  'harvesttech.en.alibaba.com/contactinfo.html',
#  'feilon.en.alibaba.com/contactinfo.html',
#  'scrlt.en.alibaba.com/contactinfo.html',
#  'sylstar.en.alibaba.com/contactinfo.html',
#  'aguatop1.en.alibaba.com/contactinfo.html',
#  'jshw.en.alibaba.com/contactinfo.html',
#  'jyasl.en.alibaba.com/contactinfo.html',
#  'wjxinyu.en.alibaba.com/contactinfo.html',
#  'wjzhongxin.en.alibaba.com/contactinfo.html',
#  'baoyuan168.en.alibaba.com/contactinfo.html',
#  'zjjhxl4.en.alibaba.com/contactinfo.html',
#  'magnetwire.en.alibaba.com/contactinfo.html',
#  'wjjzdcx.en.alibaba.com/contactinfo.html',
#  'osmuntech.en.alibaba.com/contactinfo.html',
#  'nbjhxl.en.alibaba.com/contactinfo.html',
#  'lightpoint.en.alibaba.com/contactinfo.html',
#  'opoolighting.en.alibaba.com/contactinfo.html',
#  'chinapt.en.alibaba.com/contactinfo.html',
#  'qdlima.en.alibaba.com/contactinfo.html',
#  'ulightcn.en.alibaba.com/contactinfo.html',
#  'ousipu.en.alibaba.com/contactinfo.html',
#  'gzbestop.en.alibaba.com/contactinfo.html',
#  'nssclighting.en.alibaba.com/contactinfo.html',
#  'szautodragons.en.alibaba.com/contactinfo.html',
#  'cn-ss.en.alibaba.com/contactinfo.html',
#  'sd-gaoneng.en.alibaba.com/contactinfo.html',
#  'jmogl.en.alibaba.com/contactinfo.html',
#  'mlauto.en.alibaba.com/contactinfo.html',
#  'universelite.en.alibaba.com/contactinfo.html',
#  'jsczpeide.en.alibaba.com/contactinfo.html',
#  'labels.en.alibaba.com/contactinfo.html',
#  'jarmoo-flag.en.alibaba.com/contactinfo.html',
#  'cncaps.en.alibaba.com/contactinfo.html',
#  'chinacap168.en.alibaba.com/contactinfo.html',
#  'qianzun88.en.alibaba.com/contactinfo.html',
#  'yipaiartist.en.alibaba.com/contactinfo.html',
#  'my1322489615lmyc.trustpass.alibaba.com/contactinfo.html',
#  'yangyangsports.en.alibaba.com/contactinfo.html',
#  'sj-sun.en.alibaba.com/contactinfo.html',
#  'caizhu.en.alibaba.com/contactinfo.html',
#  'tops-gift.en.alibaba.com/contactinfo.html',
#  'lianxingifts.en.alibaba.com/contactinfo.html',
#  'tops1.en.alibaba.com/contactinfo.html',
#  'cinhai.en.alibaba.com/contactinfo.html',
#  'unitedcrafts2013.en.alibaba.com/contactinfo.html',
#  'unitedcrafts.en.alibaba.com/contactinfo.html',
#  'gyancheng.en.alibaba.com/contactinfo.html',
#  'desent.en.alibaba.com/contactinfo.html',
#  'gdruixin.en.alibaba.com/contactinfo.html',
#  'choyi.en.alibaba.com/contactinfo.html',
#  'lxgifts.en.alibaba.com/contactinfo.html',
#  'wristbandfamily.en.alibaba.com/contactinfo.html',
#  'siliconfactory.en.alibaba.com/contactinfo.html',
#  '51bestsilicone.en.alibaba.com/contactinfo.html',
#  'winsungifts.en.alibaba.com/contactinfo.html',
#  'changshilipin.en.alibaba.com/contactinfo.html',
#  'gudegift.en.alibaba.com/contactinfo.html',
#  'neworientalgift.en.alibaba.com/contactinfo.html',
#  'tw-silicone.en.alibaba.com/contactinfo.html',
#  'szxinyin.en.alibaba.com/contactinfo.html',
#  'zjwinsun.en.alibaba.com/contactinfo.html',
#  'lianxingift.en.alibaba.com/contactinfo.html',
#  'holywish.en.alibaba.com/contactinfo.html',
#  'dxpromotions.en.alibaba.com/contactinfo.html',
#  'bagsmaker.en.alibaba.com/contactinfo.html',
#  'daydance.en.alibaba.com/contactinfo.html',
#  'cndeqi.en.alibaba.com/contactinfo.html',
#  'everspringbags.en.alibaba.com/contactinfo.html',
#  'eachone.en.alibaba.com/contactinfo.html',
#  'sproutjewel.en.alibaba.com/contactinfo.html',
#  'jiefachina.en.alibaba.com/contactinfo.html',
#  'hstyle.en.alibaba.com/contactinfo.html',
#  'papermanufactures.en.alibaba.com/contactinfo.html',
#  'ownerparty.en.alibaba.com/contactinfo.html',
#  'myhf.en.alibaba.com/contactinfo.html',
#  'yzzxwj.en.alibaba.com/contactinfo.html',
#  'tgtoys.en.alibaba.com/contactinfo.html',
#  'mimotoy.en.alibaba.com/contactinfo.html',
#  'lenora.en.alibaba.com/contactinfo.html',
#  'yzjingmei.en.alibaba.com/contactinfo.html',
#  'levintoys.en.alibaba.com/contactinfo.html',
#  'babytoys.en.alibaba.com/contactinfo.html',
#  'nantongopera.en.alibaba.com/contactinfo.html',
#  'gotgift.en.alibaba.com/contactinfo.html',
#  'crystocraft.en.alibaba.com/contactinfo.html',
#  'xmmelody.en.alibaba.com/contactinfo.html',
#  'cnworth.en.alibaba.com/contactinfo.html',
#  'eresources.en.alibaba.com/contactinfo.html',
#  'shicheng.en.alibaba.com/contactinfo.html',
#  'jayi-display.en.alibaba.com/contactinfo.html',
#  'taiyicraft.en.alibaba.com/contactinfo.html',
#  'gqstoys.en.alibaba.com/contactinfo.html',
#  'abangda.en.alibaba.com/contactinfo.html',
#  'yzklxy.en.alibaba.com/contactinfo.html',
#  'nicecin168.en.alibaba.com/contactinfo.html',
#  'klco.en.alibaba.com/contactinfo.html',
#  'grandfaith.en.alibaba.com/contactinfo.html',
#  'jasonfootwear.en.alibaba.com/contactinfo.html',
#  'dcharmshoes.en.alibaba.com/contactinfo.html',
#  'candoshoes.en.alibaba.com/contactinfo.html',
#  'gdczhy.en.alibaba.com/contactinfo.html',
#  'simblecn.en.alibaba.com/contactinfo.html',
#  'weihongshoes.en.alibaba.com/contactinfo.html',
#  'esatoys.en.alibaba.com/contactinfo.html',
#  'keansilicon.en.alibaba.com/contactinfo.html',
#  'cnxuda.en.alibaba.com/contactinfo.html',
#  'levincrafts.en.alibaba.com/contactinfo.html',
#  'yk2008china.en.alibaba.com/contactinfo.html',
#  'bestgoalchina.en.alibaba.com/contactinfo.html',
#  'dolphineshow.en.alibaba.com/contactinfo.html',
#  'xiangtaigifts.en.alibaba.com/contactinfo.html',
#  'yolite365.en.alibaba.com/contactinfo.html',
#  'jinyufootwear.en.alibaba.com/contactinfo.html',
#  'yzhuibo.en.alibaba.com/contactinfo.html',
#  'cnsunnyway.en.alibaba.com/contactinfo.html',
#  'minyoint.en.alibaba.com/contactinfo.html',
#  'amcshoes.en.alibaba.com/contactinfo.html',
#  'zhmany.en.alibaba.com/contactinfo.html',
#  'goodshoes.en.alibaba.com/contactinfo.html',
#  'mengxian.en.alibaba.com/contactinfo.html',
#  'szchenxuan.en.alibaba.com/contactinfo.html',
#  'seavo.en.alibaba.com/contactinfo.html',
#  'luck-shoe.en.alibaba.com/contactinfo.html',
#  'qzaf.en.alibaba.com/contactinfo.html',
#  'zsdashun.en.alibaba.com/contactinfo.html',
#  'taidawood.en.alibaba.com/contactinfo.html',
#  'woodenjewelrybox.en.alibaba.com/contactinfo.html',
#  'qznanwei.en.alibaba.com/contactinfo.html',
#  'joinste.en.alibaba.com/contactinfo.html',
#  'mantimelong.en.alibaba.com/contactinfo.html',
#  'anywaygifts.en.alibaba.com/contactinfo.html',
#  'nb-soshow.en.alibaba.com/contactinfo.html',
#  'fushun.en.alibaba.com/contactinfo.html',
#  'imfield.en.alibaba.com/contactinfo.html',
#  'aofit.en.alibaba.com/contactinfo.html',
#  'summitcraft.en.alibaba.com/contactinfo.html',
#  'wonderful-gm.en.alibaba.com/contactinfo.html',
#  'daihe.en.alibaba.com/contactinfo.html',
#  'progiftspace.en.alibaba.com/contactinfo.html',
#  'bmdbox.en.alibaba.com/contactinfo.html',
#  'ogaribox.en.alibaba.com/contactinfo.html',
#  'dikina.en.alibaba.com/contactinfo.html',
#  'forever-standing.en.alibaba.com/contactinfo.html',
#  'artisans.en.alibaba.com/contactinfo.html',
#  'qzcrafts.en.alibaba.com/contactinfo.html',
#  'fionshi.en.alibaba.com/contactinfo.html',
#  'leixingifts.en.alibaba.com/contactinfo.html',
#  'artandhome.en.alibaba.com/contactinfo.html',
#  'guangjiadg.en.alibaba.com/contactinfo.html',
#  'pavia.en.alibaba.com/contactinfo.html',
#  'eeca-packaging.en.alibaba.com/contactinfo.html',
#  'shxiyuan.en.alibaba.com/contactinfo.html',
#  'sumu.en.alibaba.com/contactinfo.html',
#  'win-gene.en.alibaba.com/contactinfo.html',
#  'baohonglass.en.alibaba.com/contactinfo.html',
#  'ensfactory.en.alibaba.com/contactinfo.html',
#  'angelhalloween.en.alibaba.com/contactinfo.html',
#  'nbjoyway.en.alibaba.com/contactinfo.html',
#  'fscool.en.alibaba.com/contactinfo.html',
#  'shenzhenkj.en.alibaba.com/contactinfo.html',
#  'kefejewelry.en.alibaba.com/contactinfo.html',
#  'szbcarts.en.alibaba.com/contactinfo.html',
#  'ywdecorart.en.alibaba.com/contactinfo.html',
#  'xmhuteng.en.alibaba.com/contactinfo.html',
#  'bcarts.en.alibaba.com/contactinfo.html',
#  'zjlovehome.en.alibaba.com/contactinfo.html',
#  'art4you.en.alibaba.com/contactinfo.html',
#  'yicaipainting.en.alibaba.com/contactinfo.html',
#  'ywqilian.en.alibaba.com/contactinfo.html',
#  'melga.en.alibaba.com/contactinfo.html',
#  'artyh.en.alibaba.com/contactinfo.html',
#  'jotome.en.alibaba.com/contactinfo.html',
#  'yiwuhuilin.en.alibaba.com/contactinfo.html',
#  'suns99.en.alibaba.com/contactinfo.html',
#  'musejewellery.en.alibaba.com/contactinfo.html',
#  'jewelryplazza.en.alibaba.com/contactinfo.html',
#  'yonker.en.alibaba.com/contactinfo.html',
#  'dsjewelry.en.alibaba.com/contactinfo.html',
#  'zijie.en.alibaba.com/contactinfo.html',
#  'xpolo.en.alibaba.com/contactinfo.html',
#  'jrsr.en.alibaba.com/contactinfo.html',
#  'rgjewelry.en.alibaba.com/contactinfo.html',
#  'lefengjewelry.en.alibaba.com/contactinfo.html',
#  'xiair.en.alibaba.com/contactinfo.html',
#  'interwell.en.alibaba.com/contactinfo.html',
#  'artigifts.en.alibaba.com/contactinfo.html',
#  'estoretech.en.alibaba.com/contactinfo.html',
#  'arui.en.alibaba.com/contactinfo.html',
#  'wzjiabo.en.alibaba.com/contactinfo.html',
#  'chinayoufine.en.alibaba.com/contactinfo.html',
#  'dzsculpture.en.alibaba.com/contactinfo.html',
#  'chinanorton.en.alibaba.com/contactinfo.html',
#  'bwlandscape.en.alibaba.com/contactinfo.html',
#  'sxcraft.en.alibaba.com/contactinfo.html',
#  'nt-decoration.en.alibaba.com/contactinfo.html',
#  'oyblg.en.alibaba.com/contactinfo.html',
#  'kuanzhan.en.alibaba.com/contactinfo.html',
#  'unn.en.alibaba.com/contactinfo.html',
#  'partneroutdoors.en.alibaba.com/contactinfo.html',
#  'binte.en.alibaba.com/contactinfo.html',
#  'beautywholesome.en.alibaba.com/contactinfo.html',
#  'itecshoes.en.alibaba.com/contactinfo.html',
#  'hamso.en.alibaba.com/contactinfo.html',
#  'oullis.en.alibaba.com/contactinfo.html',
#  'tzroyal.en.alibaba.com/contactinfo.html',
#  'dancelife.en.alibaba.com/contactinfo.html',
#  'sbetter.en.alibaba.com/contactinfo.html',
#  'tutumoon.en.alibaba.com/contactinfo.html',
#  'blossomexport.en.alibaba.com/contactinfo.html',
#  'wgoodteck.en.alibaba.com/contactinfo.html',
#  'ywsheng.en.alibaba.com/contactinfo.html',
#  'jml660.en.alibaba.com/contactinfo.html',
#  'hrgarments.en.alibaba.com/contactinfo.html',
#  'mysunshines.en.alibaba.com/contactinfo.html',
#  'chinarichtoy.en.alibaba.com/contactinfo.html',
#  'biyate.en.alibaba.com/contactinfo.html',
#  'yubofootwear.en.alibaba.com/contactinfo.html',
#  'dearsmile.en.alibaba.com/contactinfo.html',
#  'sansd.en.alibaba.com/contactinfo.html',
#  'cndfh.en.alibaba.com/contactinfo.html',
#  'a3china.en.alibaba.com/contactinfo.html',
#  'yzkz.en.alibaba.com/contactinfo.html',
#  'yzihtl.en.alibaba.com/contactinfo.html',
#  'travelsky.en.alibaba.com/contactinfo.html',
#  'farvision.en.alibaba.com/contactinfo.html',
#  'customtoychina.en.alibaba.com/contactinfo.html',
#  'jiajiatoys.en.alibaba.com/contactinfo.html',
#  'harriston-toys.en.alibaba.com/contactinfo.html',
#  'aflarts.en.alibaba.com/contactinfo.html',
#  'momodo.en.alibaba.com/contactinfo.html',
#  'chinazhizhi.en.alibaba.com/contactinfo.html',
#  'sinosouth.en.alibaba.com/contactinfo.html',
#  'wcytech.en.alibaba.com/contactinfo.html',
#  'heyli.en.alibaba.com/contactinfo.html',
#  'cottondress.en.alibaba.com/contactinfo.html',
#  'ywhuijiu.en.alibaba.com/contactinfo.html',
#  'wyjn.en.alibaba.com/contactinfo.html',
#  'sgshoes.en.alibaba.com/contactinfo.html',
#  'jndamatic.en.alibaba.com/contactinfo.html',
#  'zzknown.en.alibaba.com/contactinfo.html',
#  'chinafoodmachine.en.alibaba.com/contactinfo.html',
#  'freechina.en.alibaba.com/contactinfo.html',
#  'holtec.en.alibaba.com/contactinfo.html',
#  'blossomsport.en.alibaba.com/contactinfo.html',
#  'lvsa.en.alibaba.com/contactinfo.html',
#  'ltsourcing.en.alibaba.com/contactinfo.html',
#  'dancefavourite.en.alibaba.com/contactinfo.html',
#  'cngibbon.en.alibaba.com/contactinfo.html',
#  'blacswan.en.alibaba.com/contactinfo.html',
#  'luminousclothing.en.alibaba.com/contactinfo.html',
#  'helpushine.en.alibaba.com/contactinfo.html',
#  'dancewearcn.en.alibaba.com/contactinfo.html',
#  'balletto.en.alibaba.com/contactinfo.html',
#  'danyiballet.en.alibaba.com/contactinfo.html',
#  'fibreimpex.trustpass.alibaba.com/contactinfo.html',
#  'bailidance.en.alibaba.com/contactinfo.html',
#  'pk1334654796ngkz.trustpass.alibaba.com/contactinfo.html',
#  'allwinwin.en.alibaba.com/contactinfo.html',
#  'cxtiejian.en.alibaba.com/contactinfo.html',
#  'hohhotclothing.en.alibaba.com/contactinfo.html',
#  'pyolsm.en.alibaba.com/contactinfo.html',
#  'ecoach.en.alibaba.com/contactinfo.html',
#  'youbangapparel.en.alibaba.com/contactinfo.html',
#  'uniflying.en.alibaba.com/contactinfo.html',
#  'becarin.en.alibaba.com/contactinfo.html',
#  'mangoapparel.en.alibaba.com/contactinfo.html',
#  'whatwesew.en.alibaba.com/contactinfo.html',
#  'guanshenapparel.en.alibaba.com/contactinfo.html',
#  'derala.en.alibaba.com/contactinfo.html',
#  'hzshangyou.en.alibaba.com/contactinfo.html',
#  'lanlin.en.alibaba.com/contactinfo.html',
#  'szjiaxindapacking.en.alibaba.com/contactinfo.html',
#  'omaskaluggage.en.alibaba.com/contactinfo.html',
#  'justwell.en.alibaba.com/contactinfo.html',
#  'orchiddancewear.en.alibaba.com/contactinfo.html',
#  'globaldancesupplier.en.alibaba.com/contactinfo.html',
#  'bourdance.en.alibaba.com/contactinfo.html',
#  'marysbag.en.alibaba.com/contactinfo.html',
#  'xykty.en.alibaba.com/contactinfo.html',
#  'zhongtibeili.en.alibaba.com/contactinfo.html',
#  'shuangdiesports.en.alibaba.com/contactinfo.html',
#  'yjsport.en.alibaba.com/contactinfo.html',
#  'youquansz.en.alibaba.com/contactinfo.html',
#  'shandonglangjan.en.alibaba.com/contactinfo.html',
#  'ftsport.en.alibaba.com/contactinfo.html',
#  'hbxuze.en.alibaba.com/contactinfo.html',
#  'chinahbsc.en.alibaba.com/contactinfo.html',
#  'eastony.en.alibaba.com/contactinfo.html',
#  'lollipop.en.alibaba.com/contactinfo.html',
#  'ephod.en.alibaba.com/contactinfo.html',
#  'www.alibaba.com/member/au109366983/contactinfo.html',
#  'edance.en.alibaba.com/contactinfo.html',
#  'peterkite.en.alibaba.com/contactinfo.html',
#  'special4u.en.alibaba.com/contactinfo.html',
#  'normzl.en.alibaba.com/contactinfo.html',
#  'zhuhao-dance.en.alibaba.com/contactinfo.html',
#  'jeclothing.en.alibaba.com/contactinfo.html',
#  'missyuan.en.alibaba.com/contactinfo.html',
#  'chinatianchuang.en.alibaba.com/contactinfo.html',
#  'sxqiwu.en.alibaba.com/contactinfo.html',
#  'aidenballet.en.alibaba.com/contactinfo.html',
#  'affinitybdltd.trustpass.alibaba.com/contactinfo.html',
#  'cnsijie.en.alibaba.com/contactinfo.html',
#  'xmttoys.en.alibaba.com/contactinfo.html',
#  'bighope.en.alibaba.com/contactinfo.html',
#  'dghengmei.en.alibaba.com/contactinfo.html',
#  'wutongcrafts.en.alibaba.com/contactinfo.html',
#  'keryon.en.alibaba.com/contactinfo.html',
#  'ahindustriespk.trustpass.alibaba.com/contactinfo.html',
#  'xingqingtrade.en.alibaba.com/contactinfo.html',
#  'faisysport.trustpass.alibaba.com/contactinfo.html',
#  'henanie.en.alibaba.com/contactinfo.html',
#  'ho-yuan.en.alibaba.com/contactinfo.html',
#  'cnjonsun.en.alibaba.com/contactinfo.html',
#  'sthengye.en.alibaba.com/contactinfo.html',
#  'ynfm.en.alibaba.com/contactinfo.html',
#  'littlekids.en.alibaba.com/contactinfo.html',
#  'szdongfan.en.alibaba.com/contactinfo.html',
#  'mideecostume.en.alibaba.com/contactinfo.html',
#  'higoco.en.alibaba.com/contactinfo.html',
#  'joanfar.en.alibaba.com/contactinfo.html',
#  'qzjiawei.en.alibaba.com/contactinfo.html',
#  'yiwukate.en.alibaba.com/contactinfo.html',
#  'bolijewelry.en.alibaba.com/contactinfo.html',
#  'southwell.en.alibaba.com/contactinfo.html',
#  'curlyfur.en.alibaba.com/contactinfo.html',
#  'moviefan.en.alibaba.com/contactinfo.html',
#  'hobbywin.en.alibaba.com/contactinfo.html',
#  'winhoo.en.alibaba.com/contactinfo.html',
#  'baiwudance.en.alibaba.com/contactinfo.html',
#  'babywow.en.alibaba.com/contactinfo.html',
#  'chinaconny.en.alibaba.com/contactinfo.html',
#  'huijie2018.en.alibaba.com/contactinfo.html',
#  'normzlsport.en.alibaba.com/contactinfo.html',
#  'yatutrading.en.alibaba.com/contactinfo.html',
#  'dandysports.en.alibaba.com/contactinfo.html',
#  'ddprincess.en.alibaba.com/contactinfo.html',
#  'dyhaige.en.alibaba.com/contactinfo.html',
#  'pettiskirt.en.alibaba.com/contactinfo.html',
#  'fzvision.en.alibaba.com/contactinfo.html',
#  'jixuaninflatables.en.alibaba.com/contactinfo.html',
#  'sz3rx.en.alibaba.com/contactinfo.html',
#  'dytoys.en.alibaba.com/contactinfo.html',
#  'realfine.en.alibaba.com/contactinfo.html',
#  'szzhongyi.en.alibaba.com/contactinfo.html',
#  'ideaanimation.en.alibaba.com/contactinfo.html',
#  'qys-gifts.en.alibaba.com/contactinfo.html',
#  'hroyldanceshoes.en.alibaba.com/contactinfo.html',
#  'aimaylen.en.alibaba.com/contactinfo.html',
#  'baidaishoes.en.alibaba.com/contactinfo.html',
#  'cnbrun.en.alibaba.com/contactinfo.html',
#  'lesaikoo.en.alibaba.com/contactinfo.html',
#  'bumashoes.en.alibaba.com/contactinfo.html',
#  'legstripod.en.alibaba.com/contactinfo.html',
#  'hchshoe.en.alibaba.com/contactinfo.html',
#  'gdinfinite.en.alibaba.com/contactinfo.html',
#  'alintai.en.alibaba.com/contactinfo.html',
#  'jhtn.en.alibaba.com/contactinfo.html',
#  'jmsocks.en.alibaba.com/contactinfo.html',
#  'choozii.en.alibaba.com/contactinfo.html',
#  'gcetex.en.alibaba.com/contactinfo.html',
#  'mesonshoes.en.alibaba.com/contactinfo.html',
#  'cnchoozii.en.alibaba.com/contactinfo.html',
#  'chengyinshoes.en.alibaba.com/contactinfo.html',
#  'mikemaycall.en.alibaba.com/contactinfo.html',
#  'hztf.en.alibaba.com/contactinfo.html',
#  'zcoptical.en.alibaba.com/contactinfo.html',
#  'wztimes.en.alibaba.com/contactinfo.html',
#  'beautyrich.en.alibaba.com/contactinfo.html',
#  'xincrafts.en.alibaba.com/contactinfo.html',
#  'homeme.en.alibaba.com/contactinfo.html',
#  'starbaseltd.en.alibaba.com/contactinfo.html',
#  'tzmeihuaart.en.alibaba.com/contactinfo.html',
#  'chenistory.en.alibaba.com/contactinfo.html',
#  'kovtia.en.alibaba.com/contactinfo.html',
#  'xupingitaly.en.alibaba.com/contactinfo.html',
#  'cnhancai.en.alibaba.com/contactinfo.html',
#  'minos.en.alibaba.com/contactinfo.html',
#  'weysun.en.alibaba.com/contactinfo.html',
#  'lln.en.alibaba.com/contactinfo.html',
#  'husurujewelry.en.alibaba.com/contactinfo.html',
#  'mexjewelry.en.alibaba.com/contactinfo.html',
#  'lihualp.en.alibaba.com/contactinfo.html',
#  'forewe.en.alibaba.com/contactinfo.html',
#  'cnmajor.en.alibaba.com/contactinfo.html',
#  '3dlamp.en.alibaba.com/contactinfo.html',
#  'danswell.en.alibaba.com/contactinfo.html',
#  'rkhkm.en.alibaba.com/contactinfo.html',
#  'balarul.en.alibaba.com/contactinfo.html',
#  'miyashop.en.alibaba.com/contactinfo.html',
#  'youbinjewelry.en.alibaba.com/contactinfo.html',
#  'chunnajewelry.en.alibaba.com/contactinfo.html',
#  'dressupjewelry.en.alibaba.com/contactinfo.html',
#  'bauna.en.alibaba.com/contactinfo.html',
#  'kindyjewelry.en.alibaba.com/contactinfo.html',
#  'luomisi.en.alibaba.com/contactinfo.html',
#  'ounatrading.en.alibaba.com/contactinfo.html',
#  'kinggary.en.alibaba.com/contactinfo.html',
#  'dgjinse.en.alibaba.com/contactinfo.html',
#  'mekongzone.trustpass.alibaba.com/contactinfo.html',
#  'normzlwear.en.alibaba.com/contactinfo.html',
#  'creativesportapparel.en.alibaba.com/contactinfo.html',
#  'jakcomb2b.en.alibaba.com/contactinfo.html',
#  'lirenarts.en.alibaba.com/contactinfo.html',
#  'lightpoint-tech.en.alibaba.com/contactinfo.html',
#  'mthtoys.en.alibaba.com/contactinfo.html',
#  'chinawoodwork.en.alibaba.com/contactinfo.html',
#  'aoergift.en.alibaba.com/contactinfo.html',
#  'fuh-mei.en.alibaba.com/contactinfo.html',
#  'xihechina.en.alibaba.com/contactinfo.html',
#  'ywzhankun.en.alibaba.com/contactinfo.html',
#  'winseng.en.alibaba.com/contactinfo.html',
#  'wellken.en.alibaba.com/contactinfo.html',
#  'christmas-wonderland.en.alibaba.com/contactinfo.html',
#  'langlin.en.alibaba.com/contactinfo.html',
#  'toppingood.en.alibaba.com/contactinfo.html',
#  'china-prints.en.alibaba.com/contactinfo.html',
#  'artuland.en.alibaba.com/contactinfo.html',
#  'noah-art.en.alibaba.com/contactinfo.html',
#  'eager.en.alibaba.com/contactinfo.html',
#  'hongwuart.en.alibaba.com/contactinfo.html',
#  'yhart.en.alibaba.com/contactinfo.html',
#  'u2-art.en.alibaba.com/contactinfo.html',
#  'www.alibaba.com/member/pk110992002/contactinfo.html',
#  'bannerind.en.alibaba.com/contactinfo.html',
#  'chengyin.en.alibaba.com/contactinfo.html',
#  'unikersport.en.alibaba.com/contactinfo.html',
#  'provins.en.alibaba.com/contactinfo.html',
#  'dadiousbaby.en.alibaba.com/contactinfo.html',
#  'goblin.en.alibaba.com/contactinfo.html',
#  'maituotrade.en.alibaba.com/contactinfo.html',
#  'kjfashion.en.alibaba.com/contactinfo.html',
#  'tzzhenxing.en.alibaba.com/contactinfo.html',
#  'aslipper.en.alibaba.com/contactinfo.html',
#  'jybelinda.en.alibaba.com/contactinfo.html',
#  'obrilliant.en.alibaba.com/contactinfo.html',
#  'hbbgl.en.alibaba.com/contactinfo.html',
#  'cnbaijun.en.alibaba.com/contactinfo.html',
#  'jxwatcher.en.alibaba.com/contactinfo.html',
#  'turab.trustpass.alibaba.com/contactinfo.html',
#  'mainikesi.en.alibaba.com/contactinfo.html',
#  'lamjo.en.alibaba.com/contactinfo.html',
#  'ausbro.en.alibaba.com/contactinfo.html',
#  'sinoknit.en.alibaba.com/contactinfo.html',
#  'hzzhongzhi.en.alibaba.com/contactinfo.html',
#  'yiwusungnan.en.alibaba.com/contactinfo.html',
#  'cnshzhongdi.en.alibaba.com/contactinfo.html',
#  'fdpromo.en.alibaba.com/contactinfo.html',
#  'hzdiren.en.alibaba.com/contactinfo.html',
#  'accap06.en.alibaba.com/contactinfo.html',
#  'huasingh.en.alibaba.com/contactinfo.html',
#  'soga.trustpass.alibaba.com/contactinfo.html',
#  'pglingerie.en.alibaba.com/contactinfo.html',
#  'kapu-craft.en.alibaba.com/contactinfo.html',
#  'eco-era.en.alibaba.com/contactinfo.html',
#  'ywkapu.en.alibaba.com/contactinfo.html',
#  'huazhiartex.en.alibaba.com/contactinfo.html',
#  'butterflyinflower.en.alibaba.com/contactinfo.html',
#  'losage.en.alibaba.com/contactinfo.html',
#  'szsmilin.en.alibaba.com/contactinfo.html',
#  'focusstudio.en.alibaba.com/contactinfo.html',
#  'missionphoto.en.alibaba.com/contactinfo.html',
#  'vizgiz.en.alibaba.com/contactinfo.html',
#  'kamay.en.alibaba.com/contactinfo.html',
#  'szrenhua.en.alibaba.com/contactinfo.html',
#  'szweysun.en.alibaba.com/contactinfo.html',
#  'zsaoka.en.alibaba.com/contactinfo.html',
#  'yudafoto.en.alibaba.com/contactinfo.html',
#  'hearkenflow.en.alibaba.com/contactinfo.html',
#  'cmdvalv.en.alibaba.com/contactinfo.html',
#  'solenoid-valve.en.alibaba.com/contactinfo.html',
#  'tfjt.en.alibaba.com/contactinfo.html',
#  'gogoauto.en.alibaba.com/contactinfo.html',
#  'subei-lok.en.alibaba.com/contactinfo.html',
#  'sunthaivalve.en.alibaba.com/contactinfo.html',
#  'cnrih.en.alibaba.com/contactinfo.html',
#  'yhoujia.en.alibaba.com/contactinfo.html',
#  'fengqico.en.alibaba.com/contactinfo.html',
#  'hiseamarine.en.alibaba.com/contactinfo.html',
#  'hesu.en.alibaba.com/contactinfo.html',
#  'hrpcvalve.en.alibaba.com/contactinfo.html',
#  'tjots.en.alibaba.com/contactinfo.html',
#  'gogoatc.en.alibaba.com/contactinfo.html',
#  'zjtuoerpu.en.alibaba.com/contactinfo.html',
#  'boyuwaterproof.en.alibaba.com/contactinfo.html',
#  'puyangzhongshi.en.alibaba.com/contactinfo.html',
#  'hnzs.en.alibaba.com/contactinfo.html',
#  'zsjtzc.en.alibaba.com/contactinfo.html',
#  'sytkfm.en.alibaba.com/contactinfo.html',
#  'xiexucn.en.alibaba.com/contactinfo.html',
#  'sbmcchina.en.alibaba.com/contactinfo.html',
#  'galileo.en.alibaba.com/contactinfo.html',
#  'supvalve.en.alibaba.com/contactinfo.html',
#  'ah-sh.en.alibaba.com/contactinfo.html',
#  'de1074649299.trustpass.alibaba.com/contactinfo.html',
#  'houdevalve.en.alibaba.com/contactinfo.html',
#  'alviss.en.alibaba.com/contactinfo.html',
#  'jienuovalve.en.alibaba.com/contactinfo.html',
#  'tonglivalve.en.alibaba.com/contactinfo.html',
#  'shanxigoodwill.en.alibaba.com/contactinfo.html',
#  'cnsolid.en.alibaba.com/contactinfo.html',
#  'newdensen.en.alibaba.com/contactinfo.html',
#  'bellvalve.en.alibaba.com/contactinfo.html',
#  'yinhevalves.en.alibaba.com/contactinfo.html',
#  'gdjianda.en.alibaba.com/contactinfo.html',
#  'hongchangjufa.en.alibaba.com/contactinfo.html',
#  'tws.en.alibaba.com/contactinfo.html',
#  'casting-china.en.alibaba.com/contactinfo.html',
#  'hkaa.en.alibaba.com/contactinfo.html',
#  'lov-valve.en.alibaba.com/contactinfo.html',
#  'dddwjz.en.alibaba.com/contactinfo.html',
#  'sta-valve.en.alibaba.com/contactinfo.html',
#  'cunrui.en.alibaba.com/contactinfo.html',
#  'chinaaolong.en.alibaba.com/contactinfo.html',
#  'bote-valve.en.alibaba.com/contactinfo.html',
#  'zjfengfan.en.alibaba.com/contactinfo.html',
#  'm8ie.en.alibaba.com/contactinfo.html',
#  'kanaif.en.alibaba.com/contactinfo.html',
#  'covnapc.en.alibaba.com/contactinfo.html',
#  'yhhongteng.en.alibaba.com/contactinfo.html',
#  'migen.en.alibaba.com/contactinfo.html',
#  'syi.en.alibaba.com/contactinfo.html',
#  'cnflush.en.alibaba.com/contactinfo.html',
#  'lhorange.en.alibaba.com/contactinfo.html',
#  'shunhaikehua.en.alibaba.com/contactinfo.html',
#  'cnzjagvalves.en.alibaba.com/contactinfo.html',
#  'sefindustry.en.alibaba.com/contactinfo.html',
#  'rt-motor.en.alibaba.com/contactinfo.html',
#  'baghouse.en.alibaba.com/contactinfo.html',
#  'top-ind.en.alibaba.com/contactinfo.html',
#  'meizen-zzz.en.alibaba.com/contactinfo.html',
#  'atcgogo.en.alibaba.com/contactinfo.html',
#  'eastopbrass.en.alibaba.com/contactinfo.html',
#  'hebeimetal.en.alibaba.com/contactinfo.html',
#  'highmpa-valve.en.alibaba.com/contactinfo.html',
#  'leadwin.en.alibaba.com/contactinfo.html',
#  'grosnaplast.en.alibaba.com/contactinfo.html',
#  'wenbao-valve.en.alibaba.com/contactinfo.html',
#  'yhjunxiang.en.alibaba.com/contactinfo.html',
#  'xier.en.alibaba.com/contactinfo.html',
#  'nbqili.en.alibaba.com/contactinfo.html',
#  'jzpvcvalve.en.alibaba.com/contactinfo.html',
#  'era.en.alibaba.com/contactinfo.html',
#  'bestwayvalves.en.alibaba.com/contactinfo.html',
#  'jinzepvcballvalves.en.alibaba.com/contactinfo.html',
#  'zhongcaiwanxin.en.alibaba.com/contactinfo.html',
#  'tzzxsy.en.alibaba.com/contactinfo.html',
#  'sinco-guotai.en.alibaba.com/contactinfo.html',
#  'sunvalve.en.alibaba.com/contactinfo.html',
#  'tello.en.alibaba.com/contactinfo.html',
#  'tjlituo.en.alibaba.com/contactinfo.html',
#  'rksfluid.en.alibaba.com/contactinfo.html',
#  'cnjiegang.en.alibaba.com/contactinfo.html',
#  'qiaogongvalve.en.alibaba.com/contactinfo.html',
#  'leyonsteel.en.alibaba.com/contactinfo.html',
#  'tjtht.en.alibaba.com/contactinfo.html',
#  'bovalve.en.alibaba.com/contactinfo.html',
#  'shyiweiliuti.en.alibaba.com/contactinfo.html',
#  'cunruivalve.en.alibaba.com/contactinfo.html',
#  'chinashunshui.en.alibaba.com/contactinfo.html',
#  'wxchskf.en.alibaba.com/contactinfo.html',
#  'cnzjlink.en.alibaba.com/contactinfo.html',
#  'cntasan.en.alibaba.com/contactinfo.html',
#  'lungyun.en.alibaba.com/contactinfo.html',
#  'huto.en.alibaba.com/contactinfo.html',
#  'yestechnology.en.alibaba.com/contactinfo.html',
#  'unionvalve.en.alibaba.com/contactinfo.html',
#  'chinarealtech.en.alibaba.com/contactinfo.html',
#  'rifengkeji.en.alibaba.com/contactinfo.html',
#  'successtz.en.alibaba.com/contactinfo.html',
#  'greenplains.en.alibaba.com/contactinfo.html',
#  'didlink-valve.en.alibaba.com/contactinfo.html',
#  'shtommur.en.alibaba.com/contactinfo.html',
#  'yhjida.en.alibaba.com/contactinfo.html',
#  'zyvalve-china.en.alibaba.com/contactinfo.html',
#  'tzzishan.en.alibaba.com/contactinfo.html',
#  'cnlvke.en.alibaba.com/contactinfo.html',
#  'hengshuihongtong.en.alibaba.com/contactinfo.html',
#  'tzyingfa.en.alibaba.com/contactinfo.html',
#  'shyoko.en.alibaba.com/contactinfo.html',
#  'garlos-valve.en.alibaba.com/contactinfo.html',
#  'tzjiahao.en.alibaba.com/contactinfo.html',
#  'kangweishen.en.alibaba.com/contactinfo.html',
#  'cn1524254803zkjw.en.alibaba.com/contactinfo.html',
#  'jklong.en.alibaba.com/contactinfo.html',
#  'chyna.en.alibaba.com/contactinfo.html',
#  'watersportsadventure.en.alibaba.com/contactinfo.html',
#  'dewine.en.alibaba.com/contactinfo.html',
#  'huaquanpower.en.alibaba.com/contactinfo.html',
#  'qeepei.en.alibaba.com/contactinfo.html',
#  'dgheto.en.alibaba.com/contactinfo.html',
#  'seasummer.en.alibaba.com/contactinfo.html',
#  'winmaxsport.en.alibaba.com/contactinfo.html',
#  'valogin.en.alibaba.com/contactinfo.html',
#  'goldfitting.en.alibaba.com/contactinfo.html',
#  'tianyan.en.alibaba.com/contactinfo.html',
#  'mibond.en.alibaba.com/contactinfo.html',
#  'tzzhuosen.en.alibaba.com/contactinfo.html',
#  'yaochi.en.alibaba.com/contactinfo.html',
#  'jbhydraulic.en.alibaba.com/contactinfo.html',
#  'cenchogroup.en.alibaba.com/contactinfo.html',
#  'fulls-industry.en.alibaba.com/contactinfo.html',
#  'pingyilu.en.alibaba.com/contactinfo.html',
#  'naipaul.en.alibaba.com/contactinfo.html',
#  'tjlaike.en.alibaba.com/contactinfo.html',
#  'hshardwareco.en.alibaba.com/contactinfo.html',
#  'valwell-development.en.alibaba.com/contactinfo.html',
#  'sfanvalve.en.alibaba.com/contactinfo.html',
#  'qdiflow.en.alibaba.com/contactinfo.html',
#  'hyfy.en.alibaba.com/contactinfo.html',
#  'fbjd.en.alibaba.com/contactinfo.html',
#  'qmstainless.en.alibaba.com/contactinfo.html',
#  'cnhongya.en.alibaba.com/contactinfo.html',
#  'billextractor.en.alibaba.com/contactinfo.html',
#  'jnlongliyeya.en.alibaba.com/contactinfo.html',
#  'bundor.en.alibaba.com/contactinfo.html',
#  'covna.en.alibaba.com/contactinfo.html',
#  'huahuivalve.en.alibaba.com/contactinfo.html',
#  'flowx.en.alibaba.com/contactinfo.html',
#  'quencyoil.en.alibaba.com/contactinfo.html',
#  'kailing.en.alibaba.com/contactinfo.html',
#  'younio.en.alibaba.com/contactinfo.html',
#  'bdvalvula.en.alibaba.com/contactinfo.html',
#  'yudongvalve.en.alibaba.com/contactinfo.html',
#  'leyonmalleable.en.alibaba.com/contactinfo.html',
#  'myzbao12345.en.alibaba.com/contactinfo.html',
#  'rifengvalve.en.alibaba.com/contactinfo.html',
#  'sanqgrouptoy.en.alibaba.com/contactinfo.html',
#  'sega-valve.en.alibaba.com/contactinfo.html',
#  'gaoshanvalve.en.alibaba.com/contactinfo.html',
#  'chinaweway.en.alibaba.com/contactinfo.html',
#  'fols.en.alibaba.com/contactinfo.html',
#  'sinpovalve.en.alibaba.com/contactinfo.html',
#  'dunyun.en.alibaba.com/contactinfo.html',
#  'hightech.en.alibaba.com/contactinfo.html',
#  'automatic.en.alibaba.com/contactinfo.html',
#  'slv-cn.en.alibaba.com/contactinfo.html',
#  'nbwode.en.alibaba.com/contactinfo.html',
#  'hblanwei.en.alibaba.com/contactinfo.html',
#  'yunyiyibiao.en.alibaba.com/contactinfo.html',
#  'drindustries.en.alibaba.com/contactinfo.html',
#  'tzhengxin.en.alibaba.com/contactinfo.html',
#  'wzlianjie.en.alibaba.com/contactinfo.html',
#  'darhor.en.alibaba.com/contactinfo.html',
#  'nbkailing.en.alibaba.com/contactinfo.html',
#  'evergreenirritech.en.alibaba.com/contactinfo.html',
#  'ywleto.en.alibaba.com/contactinfo.html',
#  'zqvalve.en.alibaba.com/contactinfo.html',
#  'cnaym.en.alibaba.com/contactinfo.html',
#  'orient8888.en.alibaba.com/contactinfo.html',
#  'zjhuihongjixie.en.alibaba.com/contactinfo.html',
#  'longva.en.alibaba.com/contactinfo.html',
#  'westernvalve.en.alibaba.com/contactinfo.html',
#  'd-hong.en.alibaba.com/contactinfo.html',
#  'liankevalve.en.alibaba.com/contactinfo.html',
#  'donjoy.en.alibaba.com/contactinfo.html',
#  'jqcopper.en.alibaba.com/contactinfo.html',
#  'yantailianke.en.alibaba.com/contactinfo.html',
#  'tzoutisi.en.alibaba.com/contactinfo.html',
#  'bonavalve.en.alibaba.com/contactinfo.html',
#  'vinsco.en.alibaba.com/contactinfo.html',
#  'wzjinghong.en.alibaba.com/contactinfo.html',
#  'kdsilicone.en.alibaba.com/contactinfo.html',
#  'tengrifasteners.en.alibaba.com/contactinfo.html',
#  'cncpart.en.alibaba.com/contactinfo.html',
#  'lmlmetalwork.en.alibaba.com/contactinfo.html',
#  'ddzckj.en.alibaba.com/contactinfo.html',
#  'dgchuanghe.en.alibaba.com/contactinfo.html',
#  'dgjiacai.en.alibaba.com/contactinfo.html',
#  'relia.en.alibaba.com/contactinfo.html',
#  'zbaiheng.en.alibaba.com/contactinfo.html',
#  'autosballbearing.en.alibaba.com/contactinfo.html',
#  'gzlifun.en.alibaba.com/contactinfo.html',
#  'rolking.en.alibaba.com/contactinfo.html',
#  'huizhongfelt.en.alibaba.com/contactinfo.html',
#  'lidariyong.en.alibaba.com/contactinfo.html',
#  'sanyuanfelt.en.alibaba.com/contactinfo.html',
#  'water-filter.en.alibaba.com/contactinfo.html',
#  'hbdibei.en.alibaba.com/contactinfo.html',
#  'wysunrise.en.alibaba.com/contactinfo.html',
#  'oemwatches.en.alibaba.com/contactinfo.html',
#  'lynnwatch.en.alibaba.com/contactinfo.html',
#  'greentada.en.alibaba.com/contactinfo.html',
#  'skysweet.en.alibaba.com/contactinfo.html',
#  'cnhonestshop.en.alibaba.com/contactinfo.html',
#  'peiluowatch.en.alibaba.com/contactinfo.html',
#  'cnsztada.en.alibaba.com/contactinfo.html',
#  'agnes.en.alibaba.com/contactinfo.html',
#  'kelfashion.en.alibaba.com/contactinfo.html',
#  'megaplant.en.alibaba.com/contactinfo.html',
#  'bouncia.en.alibaba.com/contactinfo.html',
#  'sayokchina.en.alibaba.com/contactinfo.html',
#  'allshing.en.alibaba.com/contactinfo.html',
#  'inflatable.en.alibaba.com/contactinfo.html',
#  'ywmart.en.alibaba.com/contactinfo.html',
#  'dgtest.en.alibaba.com/contactinfo.html',
#  'pakfairindustries.trustpass.alibaba.com/contactinfo.html',
#  'fangyuantest.en.alibaba.com/contactinfo.html',
#  'winsir.en.alibaba.com/contactinfo.html',
#  'jnhxtest.en.alibaba.com/contactinfo.html',
#  'mjcloth.en.alibaba.com/contactinfo.html',
#  'zltester.en.alibaba.com/contactinfo.html',
#  'guiyun.en.alibaba.com/contactinfo.html',
#  'yaoke.en.alibaba.com/contactinfo.html',
#  'taisheng888.en.alibaba.com/contactinfo.html',
#  'yazhebridal.en.alibaba.com/contactinfo.html',
#  'rongsenzhiai.en.alibaba.com/contactinfo.html',
#  '860512.en.alibaba.com/contactinfo.html',
#  'charmgirl.en.alibaba.com/contactinfo.html',
#  'cswn.en.alibaba.com/contactinfo.html',
#  'morilidress.en.alibaba.com/contactinfo.html',
#  'gxsdl.en.alibaba.com/contactinfo.html',
#  'aibaowedding.en.alibaba.com/contactinfo.html',
#  'yqcreation.en.alibaba.com/contactinfo.html',
#  'fuhoascend.en.alibaba.com/contactinfo.html',
#  'surgivalley.trustpass.alibaba.com/contactinfo.html',
#  'sunuplifestyle.en.alibaba.com/contactinfo.html',
#  'enovart.en.alibaba.com/contactinfo.html',
#  'sema.en.alibaba.com/contactinfo.html',
#  'lefisher.en.alibaba.com/contactinfo.html',
#  'omobo.en.alibaba.com/contactinfo.html',
#  'greenbaby007.en.alibaba.com/contactinfo.html',
#  'lworld.en.alibaba.com/contactinfo.html',
#  'ccecasters.en.alibaba.com/contactinfo.html',
#  'syzmachine.en.alibaba.com/contactinfo.html',
#  'unionlever.en.alibaba.com/contactinfo.html',
#  'tersery.en.alibaba.com/contactinfo.html',
#  'yingda-gd.en.alibaba.com/contactinfo.html',
#  'dajincaster.en.alibaba.com/contactinfo.html',
#  'china-hardware.en.alibaba.com/contactinfo.html',
#  'trihope.en.alibaba.com/contactinfo.html',
#  'hesther.en.alibaba.com/contactinfo.html',
#  'scbearing.en.alibaba.com/contactinfo.html',
#  'qdgiant.en.alibaba.com/contactinfo.html',
#  'sunrise-cn.en.alibaba.com/contactinfo.html',
#  'chinahangfa.en.alibaba.com/contactinfo.html',
#  'qdlangwei.en.alibaba.com/contactinfo.html',
#  'qdmetal.en.alibaba.com/contactinfo.html',
#  'huilixing.en.alibaba.com/contactinfo.html',
#  'stardrawing.en.alibaba.com/contactinfo.html',
#  'haidai.en.alibaba.com/contactinfo.html',
#  'smbyarn.en.alibaba.com/contactinfo.html',
#  'rope-machine.en.alibaba.com/contactinfo.html',
#  'yirunchina.en.alibaba.com/contactinfo.html',
#  'lutongsuliao.en.alibaba.com/contactinfo.html',
#  'guomaoknitting.en.alibaba.com/contactinfo.html',
#  'laizhouyibang.en.alibaba.com/contactinfo.html',
#  'hitechcord.en.alibaba.com/contactinfo.html',
#  'ropemachine.en.alibaba.com/contactinfo.html',
#  'shaheplasticmachinery.en.alibaba.com/contactinfo.html',
#  'dxsjwj.en.alibaba.com/contactinfo.html',
#  'wbdecor.en.alibaba.com/contactinfo.html',
#  'partysupplies.en.alibaba.com/contactinfo.html',
#  'szalberttoy.en.alibaba.com/contactinfo.html',
#  'jsglasscrafts.en.alibaba.com/contactinfo.html',
#  'esmartliving.en.alibaba.com/contactinfo.html',
#  'labeol.en.alibaba.com/contactinfo.html',
#  'joyeeparty.en.alibaba.com/contactinfo.html',
#  'neon-glo.en.alibaba.com/contactinfo.html',
#  'ywsun.en.alibaba.com/contactinfo.html',
#  'jingou.en.alibaba.com/contactinfo.html',
#  'reboundsport.en.alibaba.com/contactinfo.html',
#  'shbestwill.en.alibaba.com/contactinfo.html',
#  'zpfelt.en.alibaba.com/contactinfo.html',
#  'zonch.en.alibaba.com/contactinfo.html',
#  'cninflatables.en.alibaba.com/contactinfo.html',
#  'nbfanhao.en.alibaba.com/contactinfo.html',
#  'minglitoy.en.alibaba.com/contactinfo.html',
#  'scole.en.alibaba.com/contactinfo.html',
#  'bacme.en.alibaba.com/contactinfo.html',
#  'cnball.en.alibaba.com/contactinfo.html',
#  'nbbeland.en.alibaba.com/contactinfo.html',
#  'shinee.en.alibaba.com/contactinfo.html',
#  'chenyunsports.en.alibaba.com/contactinfo.html',
#  'hwsport.en.alibaba.com/contactinfo.html',
#  'nb-nx.en.alibaba.com/contactinfo.html',
#  'cengain.en.alibaba.com/contactinfo.html',
#  'jiayangsolar.en.alibaba.com/contactinfo.html',
#  'sznewgift.en.alibaba.com/contactinfo.html',
#  'ucaremeter.en.alibaba.com/contactinfo.html',
#  'shantulighting.en.alibaba.com/contactinfo.html',
#  'szlllp.en.alibaba.com/contactinfo.html',
#  'gewilson.en.alibaba.com/contactinfo.html',
#  'lejin.en.alibaba.com/contactinfo.html',
#  'ydfsmart.en.alibaba.com/contactinfo.html',
#  'stoter.en.alibaba.com/contactinfo.html',
#  'forestpacking.en.alibaba.com/contactinfo.html',
#  'kudi.en.alibaba.com/contactinfo.html',
#  'dougez.en.alibaba.com/contactinfo.html',
#  'holyart.en.alibaba.com/contactinfo.html',
#  'qqcraft.en.alibaba.com/contactinfo.html',
#  'jianicat.en.alibaba.com/contactinfo.html',
#  'inspirerpet.en.alibaba.com/contactinfo.html',
#  'xinyuanart.en.alibaba.com/contactinfo.html',
#  'jilinevercreation.en.alibaba.com/contactinfo.html',
#  'wujicrafts.en.alibaba.com/contactinfo.html',
#  'muspire.en.alibaba.com/contactinfo.html',
#  'ranaoverseasindia.trustpass.alibaba.com/contactinfo.html',
#  'progiftspacecn.en.alibaba.com/contactinfo.html',
#  'dgzxmy.en.alibaba.com/contactinfo.html',
#  'tianshancraft.en.alibaba.com/contactinfo.html',
#  'xameiguang.en.alibaba.com/contactinfo.html',
#  'preservedboxwood.en.alibaba.com/contactinfo.html',
#  'decomesh.en.alibaba.com/contactinfo.html',
#  'ywyxds.en.alibaba.com/contactinfo.html',
#  'szsenhy.en.alibaba.com/contactinfo.html',
#  'nuanpin.en.alibaba.com/contactinfo.html',
#  'guangyuan-arts.en.alibaba.com/contactinfo.html',
#  'sygykj.en.alibaba.com/contactinfo.html',
#  'allsmart.en.alibaba.com/contactinfo.html',
#  'anqiujiarui.en.alibaba.com/contactinfo.html',
#  'libertyport.en.alibaba.com/contactinfo.html',
#  'charmkeytextile.en.alibaba.com/contactinfo.html',
#  'eccess.en.alibaba.com/contactinfo.html',
#  'charmkey.en.alibaba.com/contactinfo.html',
#  'kingbirdcraft.en.alibaba.com/contactinfo.html',
#  'txbojay.en.alibaba.com/contactinfo.html',
#  'bojaytex.en.alibaba.com/contactinfo.html',
#  'txgreat.en.alibaba.com/contactinfo.html',
#  'jschenglong.en.alibaba.com/contactinfo.html',
#  'wennuochina.en.alibaba.com/contactinfo.html',
#  'icsunrise.en.alibaba.com/contactinfo.html',
#  'firstpen.en.alibaba.com/contactinfo.html',
#  'zhenghua.en.alibaba.com/contactinfo.html',
#  'darwinpen.en.alibaba.com/contactinfo.html',
#  'tjmjd.en.alibaba.com/contactinfo.html',
#  'szgiftoy.en.alibaba.com/contactinfo.html',
#  'visionintl.en.alibaba.com/contactinfo.html',
#  'eego.en.alibaba.com/contactinfo.html',
#  'qibaosen.en.alibaba.com/contactinfo.html',
#  'nbinshine.en.alibaba.com/contactinfo.html',
#  'happystationery.en.alibaba.com/contactinfo.html',
#  'zsyibao.en.alibaba.com/contactinfo.html',
#  'giftpromo.en.alibaba.com/contactinfo.html',
#  'anc-gift.en.alibaba.com/contactinfo.html',
#  'dgtybg.en.alibaba.com/contactinfo.html',
#  'minigifts.en.alibaba.com/contactinfo.html',
#  'v-sintl.en.alibaba.com/contactinfo.html',
#  'ywfqzm.en.alibaba.com/contactinfo.html',
#  'carqilight.en.alibaba.com/contactinfo.html',
#  'trutecled.en.alibaba.com/contactinfo.html',
#  'ftl666.en.alibaba.com/contactinfo.html',
#  'hyluxtek.en.alibaba.com/contactinfo.html',
#  'techone.en.alibaba.com/contactinfo.html',
#  'gmhz.en.alibaba.com/contactinfo.html',
#  'noerka.en.alibaba.com/contactinfo.html',
#  'lumencn.en.alibaba.com/contactinfo.html',
#  'xenon.en.alibaba.com/contactinfo.html',
#  'sreelight.en.alibaba.com/contactinfo.html',
#  'ledbesttube.en.alibaba.com/contactinfo.html',
#  'betterlite.en.alibaba.com/contactinfo.html',
#  'lhhilight.en.alibaba.com/contactinfo.html',
#  'li-light.en.alibaba.com/contactinfo.html',
#  'infelite.en.alibaba.com/contactinfo.html',
#  'ok-lite.en.alibaba.com/contactinfo.html',
#  'pufaled.en.alibaba.com/contactinfo.html',
#  'romanso.en.alibaba.com/contactinfo.html',
#  'vlikelighting.en.alibaba.com/contactinfo.html',
#  'popnow.en.alibaba.com/contactinfo.html',
#  'yurao.en.alibaba.com/contactinfo.html',
#  'hid-led.en.alibaba.com/contactinfo.html',
#  'szokayhydroponics.en.alibaba.com/contactinfo.html',
#  'lightechled.en.alibaba.com/contactinfo.html',
#  'b-deals.en.alibaba.com/contactinfo.html',
#  'yylamps.en.alibaba.com/contactinfo.html',
#  'nbjunyun.en.alibaba.com/contactinfo.html',
#  'townlite.en.alibaba.com/contactinfo.html',
#  'kingratelighting.en.alibaba.com/contactinfo.html',
#  'bersn.en.alibaba.com/contactinfo.html',
#  'xingzhiye.en.alibaba.com/contactinfo.html',
#  'zgchangfa.en.alibaba.com/contactinfo.html',
#  'wing.en.alibaba.com/contactinfo.html',
#  'bnchg.en.alibaba.com/contactinfo.html',
#  'chinaxqs.en.alibaba.com/contactinfo.html',
#  'enlightelectronics.en.alibaba.com/contactinfo.html',
#  'spmlighting.en.alibaba.com/contactinfo.html',
#  'legelite.en.alibaba.com/contactinfo.html',
#  'szjiangjing.en.alibaba.com/contactinfo.html',
#  'jiateming.en.alibaba.com/contactinfo.html',
#  'focalvalue.en.alibaba.com/contactinfo.html',
#  'longood.en.alibaba.com/contactinfo.html',
#  'cnwingspeed.en.alibaba.com/contactinfo.html',
#  ...]

# %%
df2['business_supplier'][44]
# Out:
# ' Co., Ltd.'

# %%
print(df2['contacts_url'][44])
# Out:
# tiaoshun.en.alibaba.com/contactinfo.html
